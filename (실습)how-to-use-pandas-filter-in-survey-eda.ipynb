# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib as plt

from IPython.display import set_matplotlib_formats
set_matplotlib_formats("retina")

plt.style.use("seaborn-whitegrid")

# %%
raw = pd.read_csv(r"kaggle_survey_2020_responses.csv", low_memory = False)
raw.shape
# Out:
# (20037, 355)

# %%
raw.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                1838                        35-39
# 2                              289287                        30-34
# 3                                 860                        35-39
# 4                                 507                        30-34
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                   Colombia
# 2                   United States of America
# 3                                  Argentina
# 4                   United States of America
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Doctoral degree
# 2                                    Master’s degree
# 3                                  Bachelor’s degree
# 4                                    Master’s degree
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                            Student
# 2                                      Data Engineer
# 3                                  Software Engineer
# 4                                     Data Scientist
#
#                                                   Q6  \
# 0  For how many years have you been writing code ...
# 1                                         5-10 years
# 2                                         5-10 years
# 3                                        10-20 years
# 4                                         5-10 years
#
#                                            Q7_Part_1  \
# 0  What programming languages do you use on a reg...
# 1                                             Python
# 2                                             Python
# 3                                                NaN
# 4                                             Python
#
#                                            Q7_Part_2  \
# 0  What programming languages do you use on a reg...
# 1                                                  R
# 2                                                  R
# 3                                                NaN
# 4                                                NaN
#
#                                            Q7_Part_3  ...  \
# 0  What programming languages do you use on a reg...  ...
# 1                                                SQL  ...
# 2                                                SQL  ...
# 3                                                NaN  ...
# 4                                                SQL  ...
#
#                                         Q35_B_Part_2  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_3  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_4  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_5  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                       TensorBoard
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_6  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_7  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_8  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         Q35_B_Part_9  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                        Q35_B_Part_10  \
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                               None
# 4                                                NaN
#
#                                          Q35_B_OTHER
# 0  In the next 2 years, do you hope to become mor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 355 columns]

# %%
question = raw.iloc[0]     #행번호(row number)로 선택하는 방법
question
# Out:
# Time from Start to Finish (seconds)                                Duration (in seconds)
# Q1                                                           What is your age (# years)?
# Q2                                                What is your gender? - Selected Choice
# Q3                                             In which country do you currently reside?
# Q4                                     What is the highest level of formal education ...
#                                                              ...
# Q35_B_Part_7                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_8                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_9                           In the next 2 years, do you hope to become mor...
# Q35_B_Part_10                          In the next 2 years, do you hope to become mor...
# Q35_B_OTHER                            In the next 2 years, do you hope to become mor...
# Name: 0, Length: 355, dtype: object

# %%
raw.drop?

# %%
answer = raw.drop([0])
answer
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2  \
# 1                                    1838  35-39    Man
# 2                                  289287  30-34    Man
# 3                                     860  35-39    Man
# 4                                     507  30-34    Man
# 5                                      78  30-34    Man
# ...                                   ...    ...    ...
# 20032                                 126  18-21    Man
# 20033                                 566  55-59  Woman
# 20034                                 238  30-34    Man
# 20035                                 625  22-24    Man
# 20036                                1031  22-24    Man
#
#                                                       Q3  \
# 1                                               Colombia
# 2                               United States of America
# 3                                              Argentina
# 4                               United States of America
# 5                                                  Japan
# ...                                                  ...
# 20032                                             Turkey
# 20033  United Kingdom of Great Britain and Northern I...
# 20034                                             Brazil
# 20035                                              India
# 20036                                           Pakistan
#
#                                                       Q4  \
# 1                                        Doctoral degree
# 2                                        Master’s degree
# 3                                      Bachelor’s degree
# 4                                        Master’s degree
# 5                                        Master’s degree
# ...                                                  ...
# 20032  Some college/university study without earning ...
# 20033                                    Master’s degree
# 20034                                    Master’s degree
# 20035                                  Bachelor’s degree
# 20036                                    Master’s degree
#
#                               Q5           Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  \
# 1                        Student   5-10 years    Python         R       SQL
# 2                  Data Engineer   5-10 years    Python         R       SQL
# 3              Software Engineer  10-20 years       NaN       NaN       NaN
# 4                 Data Scientist   5-10 years    Python       NaN       SQL
# 5              Software Engineer    3-5 years    Python       NaN       NaN
# ...                          ...          ...       ...       ...       ...
# 20032                        NaN          NaN       NaN       NaN       NaN
# 20033     Currently not employed    20+ years    Python       NaN       NaN
# 20034         Research Scientist    < 1 years    Python       NaN       NaN
# 20035          Software Engineer    3-5 years    Python       NaN       SQL
# 20036  Machine Learning Engineer    < 1 years    Python       NaN       NaN
#
#        ...        Q35_B_Part_2 Q35_B_Part_3 Q35_B_Part_4   Q35_B_Part_5  \
# 1      ...                 NaN          NaN          NaN   TensorBoard
# 2      ...                 NaN          NaN          NaN            NaN
# 3      ...                 NaN          NaN          NaN            NaN
# 4      ...                 NaN          NaN          NaN            NaN
# 5      ...                 NaN          NaN          NaN            NaN
# ...    ...                 ...          ...          ...            ...
# 20032  ...                 NaN          NaN          NaN            NaN
# 20033  ...                 NaN          NaN          NaN            NaN
# 20034  ...                 NaN          NaN          NaN            NaN
# 20035  ...   Weights & Biases           NaN          NaN   TensorBoard
# 20036  ...   Weights & Biases           NaN          NaN            NaN
#
#       Q35_B_Part_6 Q35_B_Part_7 Q35_B_Part_8 Q35_B_Part_9 Q35_B_Part_10  \
# 1              NaN          NaN          NaN          NaN           NaN
# 2              NaN          NaN          NaN          NaN           NaN
# 3              NaN          NaN          NaN          NaN          None
# 4              NaN          NaN          NaN          NaN           NaN
# 5              NaN          NaN          NaN          NaN           NaN
# ...            ...          ...          ...          ...           ...
# 20032          NaN          NaN          NaN          NaN           NaN
# 20033          NaN          NaN          NaN          NaN          None
# 20034          NaN          NaN          NaN          NaN           NaN
# 20035          NaN          NaN      Trains           NaN           NaN
# 20036          NaN          NaN      Trains           NaN           NaN
#
#       Q35_B_OTHER
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# ...           ...
# 20032         NaN
# 20033         NaN
# 20034         NaN
# 20035         NaN
# 20036         NaN
#
# [20036 rows x 355 columns]

# %%
answer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20036 entries, 1 to 20036
# Columns: 355 entries, Time from Start to Finish (seconds) to Q35_B_OTHER
# dtypes: object(355)
# memory usage: 54.4+ MB

# %% [markdown]
# ## Q1 What is your age (#years)?

# %%
question["Q1"]
# Out:
# 'What is your age (# years)?'

# %%
answer['Q1'].value_counts(normalize = True)  * 100 # 정규화 평균을 내서 합이 1이 되게 만들어준다
# Out:
# 25-29    20.018966
# 22-24    18.895987
# 18-21    17.313835
# 30-34    14.029746
# 35-39     9.937113
# 40-44     6.972450
# 45-49     4.931124
# 50-54     3.483729
# 55-59     2.051308
# 60-69     1.986424
# 70+       0.379317
# Name: Q1, dtype: float64

# %%
answer['Q1'].value_counts().sort_index().plot() 
# .sort_index()는 인덱스(index)를 기준으로, .sort_values()는 컬럼의 값을 기준으로 데이터를 정렬
# Out:
# <AxesSubplot:>

# %%
answer['Q1'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data = answer.sort_values('Q1'), x = 'Q1').set_title(question['Q1'])
# Out:
# Text(0.5, 1.0, 'What is your age (# years)?')

# %%
Q1 = answer['Q1'].value_counts().sort_index()
Q1
sns.countplot(data = answer.sort_values('Q1'), 
              x = 'Q1',
              palette = 'Blues_r').set_title(question['Q1'])
# Out:
# Text(0.5, 1.0, 'What is your age (# years)?')

# %% [markdown]
# ## Q2 What is your gender? - Selected Choice

# %%
question_no = 'Q2'
Q2 = answer[question_no].value_counts(ascending = False)
Q2
# Out:
# Man                        15789
# Woman                       3878
# Prefer not to say            263
# Prefer to self-describe       54
# Nonbinary                     52
# Name: Q2, dtype: int64

# %%
sns.countplot(data = answer,
             y = question_no).set_title(question[question_no])
# Out:
# Text(0.5, 1.0, 'What is your gender? - Selected Choice')

# %%
answer['Q1'].value_counts()
# Out:
# 25-29    4011
# 22-24    3786
# 18-21    3469
# 30-34    2811
# 35-39    1991
# 40-44    1397
# 45-49     988
# 50-54     698
# 55-59     411
# 60-69     398
# 70+        76
# Name: Q1, dtype: int64

# %%
q1q2 = pd.crosstab(answer['Q1'], answer['Q2'])

# %%
q1q2[['Man', 'Woman']]
# Out:
# Q2      Man  Woman
# Q1
# 18-21  2611    796
# 22-24  2838    886
# 25-29  3128    819
# 30-34  2246    504
# 35-39  1581    368
# 40-44  1153    222
# 45-49   840    126
# 50-54   605     81
# 55-59   353     45
# 60-69   362     29
# 70+      72      2

# %%
q1q2 = pd.crosstab(answer['Q1'], answer['Q2'])
q1q2[['Man', 'Woman']].plot()
# Out:
# <AxesSubplot:xlabel='Q1'>

# %%
q1q2 = pd.crosstab(answer['Q1'], answer['Q2'])
q1q2[['Man', 'Woman']].plot.bar(rot = 30)  #bar(rot)  rotation각도 설정
# Out:
# <AxesSubplot:xlabel='Q1'>

# %%
q1q2[['Man', 'Woman']].sort_index(ascending = False).plot.barh(rot = 0, figsize = (10, 7), title = "Age & Gender")
# Out:
# <AxesSubplot:title={'center':'Age & Gender'}, ylabel='Q1'>

# %%
#seaborn 그리기
plt.figure.Figure(figsize = (10, 6))
sns.countplot(data = answer.sort_values('Q1'), x = 'Q1', hue = 'Q2').set_title('Age & Gender')
# Out:
# Text(0.5, 1.0, 'Age & Gender')

# %%
q1q2 = pd.crosstab(answer["Q1"], answer['Q2'])
q1q2[['Man', 'Woman']].plot.bar(rot = 0)
# Out:
# <AxesSubplot:xlabel='Q1'>

# %%
q1q2[['Man', 'Woman']].sort_index(ascending = False).plot.barh(figsize = (10, 6), title = "Age & Gender")
# Out:
# <AxesSubplot:title={'center':'Age & Gender'}, ylabel='Q1'>

# %%
plt.figure.Figure(figsize = (10, 6))
sns.countplot(data = answer.sort_values('Q1'), x = "Q1", hue = "Q2").set_title("Age & Gender")
# Out:
# Text(0.5, 1.0, 'Age & Gender')

# %% [markdown]
# # Q3 In which country do you currently reside?

# %% [markdown]
# ### 📊define show_countplot_by_qno

# %%
answer
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2  \
# 1                                    1838  35-39    Man
# 2                                  289287  30-34    Man
# 3                                     860  35-39    Man
# 4                                     507  30-34    Man
# 5                                      78  30-34    Man
# ...                                   ...    ...    ...
# 20032                                 126  18-21    Man
# 20033                                 566  55-59  Woman
# 20034                                 238  30-34    Man
# 20035                                 625  22-24    Man
# 20036                                1031  22-24    Man
#
#                                                       Q3  \
# 1                                               Colombia
# 2                               United States of America
# 3                                              Argentina
# 4                               United States of America
# 5                                                  Japan
# ...                                                  ...
# 20032                                             Turkey
# 20033  United Kingdom of Great Britain and Northern I...
# 20034                                             Brazil
# 20035                                              India
# 20036                                           Pakistan
#
#                                                       Q4  \
# 1                                        Doctoral degree
# 2                                        Master’s degree
# 3                                      Bachelor’s degree
# 4                                        Master’s degree
# 5                                        Master’s degree
# ...                                                  ...
# 20032  Some college/university study without earning ...
# 20033                                    Master’s degree
# 20034                                    Master’s degree
# 20035                                  Bachelor’s degree
# 20036                                    Master’s degree
#
#                               Q5           Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  \
# 1                        Student   5-10 years    Python         R       SQL
# 2                  Data Engineer   5-10 years    Python         R       SQL
# 3              Software Engineer  10-20 years       NaN       NaN       NaN
# 4                 Data Scientist   5-10 years    Python       NaN       SQL
# 5              Software Engineer    3-5 years    Python       NaN       NaN
# ...                          ...          ...       ...       ...       ...
# 20032                        NaN          NaN       NaN       NaN       NaN
# 20033     Currently not employed    20+ years    Python       NaN       NaN
# 20034         Research Scientist    < 1 years    Python       NaN       NaN
# 20035          Software Engineer    3-5 years    Python       NaN       SQL
# 20036  Machine Learning Engineer    < 1 years    Python       NaN       NaN
#
#        ...        Q35_B_Part_2 Q35_B_Part_3 Q35_B_Part_4   Q35_B_Part_5  \
# 1      ...                 NaN          NaN          NaN   TensorBoard
# 2      ...                 NaN          NaN          NaN            NaN
# 3      ...                 NaN          NaN          NaN            NaN
# 4      ...                 NaN          NaN          NaN            NaN
# 5      ...                 NaN          NaN          NaN            NaN
# ...    ...                 ...          ...          ...            ...
# 20032  ...                 NaN          NaN          NaN            NaN
# 20033  ...                 NaN          NaN          NaN            NaN
# 20034  ...                 NaN          NaN          NaN            NaN
# 20035  ...   Weights & Biases           NaN          NaN   TensorBoard
# 20036  ...   Weights & Biases           NaN          NaN            NaN
#
#       Q35_B_Part_6 Q35_B_Part_7 Q35_B_Part_8 Q35_B_Part_9 Q35_B_Part_10  \
# 1              NaN          NaN          NaN          NaN           NaN
# 2              NaN          NaN          NaN          NaN           NaN
# 3              NaN          NaN          NaN          NaN          None
# 4              NaN          NaN          NaN          NaN           NaN
# 5              NaN          NaN          NaN          NaN           NaN
# ...            ...          ...          ...          ...           ...
# 20032          NaN          NaN          NaN          NaN           NaN
# 20033          NaN          NaN          NaN          NaN          None
# 20034          NaN          NaN          NaN          NaN           NaN
# 20035          NaN          NaN      Trains           NaN           NaN
# 20036          NaN          NaN      Trains           NaN           NaN
#
#       Q35_B_OTHER
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# ...           ...
# 20032         NaN
# 20033         NaN
# 20034         NaN
# 20035         NaN
# 20036         NaN
#
# [20036 rows x 355 columns]

# %%
q1_cols = answer['Q1'].value_counts().sort_index().index.tolist()
q1_cols
# Out:
# ['18-21',
#  '22-24',
#  '25-29',
#  '30-34',
#  '35-39',
#  '40-44',
#  '45-49',
#  '50-54',
#  '55-59',
#  '60-69',
#  '70+']

# %%
answer['Q3'].value_counts().index
# Out:
# Index(['India', 'United States of America', 'Other', 'Brazil', 'Japan',
#        'Russia', 'United Kingdom of Great Britain and Northern Ireland',
#        'Nigeria', 'China', 'Germany', 'Turkey', 'Spain', 'France', 'Canada',
#        'Indonesia', 'Pakistan', 'Italy', 'Taiwan', 'Australia', 'Mexico',
#        'South Korea', 'Egypt', 'Colombia', 'Ukraine',
#        'Iran, Islamic Republic of...', 'Kenya', 'Netherlands', 'Singapore',
#        'Poland', 'Viet Nam', 'Bangladesh', 'South Africa', 'Argentina',
#        'Malaysia', 'Morocco', 'Thailand', 'Portugal', 'Greece', 'Tunisia',
#        'Philippines', 'Israel', 'Peru', 'Chile', 'Sweden', 'Republic of Korea',
#        'Saudi Arabia', 'Sri Lanka', 'Switzerland', 'Nepal', 'Romania',
#        'Belgium', 'United Arab Emirates', 'Belarus', 'Ireland', 'Ghana'],
#       dtype='object')

# %%
def show_countplot_by_qno(qno, fsize = (10, 6), order = None):
    
    if not order : 
        order = answer[qno].value_counts().index
    
    plt.figure.Figure(figsize = fsize)
    sns.countplot(data = answer, y = qno,
                 order = order,
                 palette  = 'Blues_r').set_title(question[qno])
        
        
show_countplot_by_qno('Q3')

# %%
show_countplot_by_qno?
show_countplot_by_qno??

# %%
show_countplot_by_qno('Q3', fsize = (17, 17))

# %% [markdown]
# ## Q4 🎓 What is the highest level of formal education that you have attained or plan to attain within the next 2 years?

# %%
show_countplot_by_qno('Q4')

# %% [markdown]
# ## Q6 For how many years have you been writing code and/or programming?

# %%
show_countplot_by_qno('Q6')

# %%
q6_cols = ['I have never written code', '< 1 years', '1-2 years', '3-5 years', '5-10 years',  
       '10-20 years', '20+ years']

# %%
show_countplot_by_qno('Q6', order = q6_cols)

# %% [markdown]
# ## Q7 What programming languages do you use on a regular basis? (Select all that apply)
#
# ### 🐼 pandas filter & describe 🗂

# %%
question.filter(regex = 'Q7')[0].split('-')[0]
# Out:
# 'What programming languages do you use on a regular basis? (Select all that apply) '

# %%
answer_Q7 = answer.filter(regex = 'Q7')
answer_Q7
# Out:
#       Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6   Q7_Part_7  \
# 1        Python         R       SQL         C       NaN       NaN  Javascript
# 2        Python         R       SQL       NaN       NaN       NaN         NaN
# 3           NaN       NaN       NaN       NaN       NaN      Java  Javascript
# 4        Python       NaN       SQL       NaN       NaN       NaN         NaN
# 5        Python       NaN       NaN       NaN       NaN       NaN         NaN
# ...         ...       ...       ...       ...       ...       ...         ...
# 20032       NaN       NaN       NaN       NaN       NaN       NaN         NaN
# 20033    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 20034    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 20035    Python       NaN       SQL         C       NaN      Java  Javascript
# 20036    Python       NaN       NaN       NaN       NaN       NaN         NaN
#
#       Q7_Part_8 Q7_Part_9 Q7_Part_10 Q7_Part_11 Q7_Part_12 Q7_OTHER
# 1           NaN       NaN        NaN     MATLAB        NaN    Other
# 2           NaN       NaN        NaN        NaN        NaN      NaN
# 3           NaN       NaN       Bash        NaN        NaN      NaN
# 4           NaN       NaN       Bash        NaN        NaN      NaN
# 5           NaN       NaN        NaN        NaN        NaN      NaN
# ...         ...       ...        ...        ...        ...      ...
# 20032       NaN       NaN        NaN        NaN        NaN      NaN
# 20033       NaN       NaN        NaN        NaN        NaN      NaN
# 20034       NaN       NaN        NaN        NaN        NaN      NaN
# 20035       NaN       NaN        NaN        NaN        NaN      NaN
# 20036       NaN       NaN        NaN        NaN        NaN      NaN
#
# [20036 rows x 13 columns]

# %%
answer_Q7.notnull().sum()
# Out:
# Q7_Part_1     15530
# Q7_Part_2      4277
# Q7_Part_3      7535
# Q7_Part_4      3315
# Q7_Part_5      3827
# Q7_Part_6      3367
# Q7_Part_7      2995
# Q7_Part_8       262
# Q7_Part_9       198
# Q7_Part_10     1776
# Q7_Part_11     2217
# Q7_Part_12      206
# Q7_OTHER       1945
# dtype: int64

# %%
answerQ7_desc = answer_Q7.describe()
answerQ7_desc
# Out:
#        Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6  \
# count      15530      4277      7535      3315      3827      3367
# unique         1         1         1         1         1         1
# top       Python         R       SQL         C       C++      Java
# freq       15530      4277      7535      3315      3827      3367
#
#          Q7_Part_7 Q7_Part_8 Q7_Part_9 Q7_Part_10 Q7_Part_11 Q7_Part_12  \
# count         2995       262       198       1776       2217        206
# unique           1         1         1          1          1          1
# top     Javascript     Julia     Swift       Bash     MATLAB       None
# freq          2995       262       198       1776       2217        206
#
#        Q7_OTHER
# count      1945
# unique        1
# top       Other
# freq       1945

# %%
answerQ7_desc.loc[['top', 'count']].T.set_index('top').plot.bar()
# Out:
# <AxesSubplot:xlabel='top'>

# %%
question.filter(regex = 'Q7')[0].split('-')[0]
# Out:
# 'What programming languages do you use on a regular basis? (Select all that apply) '

# %%
answer_Q7 = answer.filter(regex = 'Q7')
answer_Q7
# Out:
#       Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6   Q7_Part_7  \
# 1        Python         R       SQL         C       NaN       NaN  Javascript
# 2        Python         R       SQL       NaN       NaN       NaN         NaN
# 3           NaN       NaN       NaN       NaN       NaN      Java  Javascript
# 4        Python       NaN       SQL       NaN       NaN       NaN         NaN
# 5        Python       NaN       NaN       NaN       NaN       NaN         NaN
# ...         ...       ...       ...       ...       ...       ...         ...
# 20032       NaN       NaN       NaN       NaN       NaN       NaN         NaN
# 20033    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 20034    Python       NaN       NaN       NaN       NaN       NaN         NaN
# 20035    Python       NaN       SQL         C       NaN      Java  Javascript
# 20036    Python       NaN       NaN       NaN       NaN       NaN         NaN
#
#       Q7_Part_8 Q7_Part_9 Q7_Part_10 Q7_Part_11 Q7_Part_12 Q7_OTHER
# 1           NaN       NaN        NaN     MATLAB        NaN    Other
# 2           NaN       NaN        NaN        NaN        NaN      NaN
# 3           NaN       NaN       Bash        NaN        NaN      NaN
# 4           NaN       NaN       Bash        NaN        NaN      NaN
# 5           NaN       NaN        NaN        NaN        NaN      NaN
# ...         ...       ...        ...        ...        ...      ...
# 20032       NaN       NaN        NaN        NaN        NaN      NaN
# 20033       NaN       NaN        NaN        NaN        NaN      NaN
# 20034       NaN       NaN        NaN        NaN        NaN      NaN
# 20035       NaN       NaN        NaN        NaN        NaN      NaN
# 20036       NaN       NaN        NaN        NaN        NaN      NaN
#
# [20036 rows x 13 columns]

# %%
answer_Q7_desc = answer_Q7.describe()
answer_Q7_desc
# Out:
#        Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6  \
# count      15530      4277      7535      3315      3827      3367
# unique         1         1         1         1         1         1
# top       Python         R       SQL         C       C++      Java
# freq       15530      4277      7535      3315      3827      3367
#
#          Q7_Part_7 Q7_Part_8 Q7_Part_9 Q7_Part_10 Q7_Part_11 Q7_Part_12  \
# count         2995       262       198       1776       2217        206
# unique           1         1         1          1          1          1
# top     Javascript     Julia     Swift       Bash     MATLAB       None
# freq          2995       262       198       1776       2217        206
#
#        Q7_OTHER
# count      1945
# unique        1
# top       Other
# freq       1945

# %%
answer_Q7_count = answer_Q7_desc.loc[['top', 'count']].T.set_index('top').sort_values('count', ascending = False)
answer_Q7_count
# Out:
#             count
# top
# Python      15530
# SQL          7535
# R            4277
# C++          3827
# Java         3367
# C            3315
# Javascript   2995
# MATLAB       2217
# Other        1945
# Bash         1776
# Julia         262
# None          206
# Swift         198

# %%
question.filter(regex = 'Q7')[0].split('-')[0]
# Out:
# 'What programming languages do you use on a regular basis? (Select all that apply) '

# %%
q7_title = question.filter(regex = 'Q7')[0].split('-')[0]
sns.barplot(data = answer_Q7_count, y = answer_Q7_count.index, x = 'count', palette = 'Blues_r').set_title(q7_title)
# Out:
# Text(0.5, 1.0, 'What programming languages do you use on a regular basis? (Select all that apply) ')

# %% [markdown]
# ### 🗂 How to get title in multiple choice question

# %%
q7_title = question.filter(regex = 'Q7')[0].split('-')[0]
sns.barplot(data = answer_Q7_count, 
            y = answer_Q7_count.index, 
            x = 'count', 
            palette = 'Blues_r').set_title(q7_title)
# Out:
# Text(0.5, 1.0, 'What programming languages do you use on a regular basis? (Select all that apply) ')

# %% [markdown]
# ### 🏷 define get_question_title function

# %%
question.index
# Out:
# Index(['Time from Start to Finish (seconds)', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5',
#        'Q6', 'Q7_Part_1', 'Q7_Part_2', 'Q7_Part_3',
#        ...
#        'Q35_B_Part_2', 'Q35_B_Part_3', 'Q35_B_Part_4', 'Q35_B_Part_5',
#        'Q35_B_Part_6', 'Q35_B_Part_7', 'Q35_B_Part_8', 'Q35_B_Part_9',
#        'Q35_B_Part_10', 'Q35_B_OTHER'],
#       dtype='object', length=355)

# %%
def get_question_title_by_qno(qno):
    if qno in question.index:
        return question[qno]
    else:
        q_no = question.filter(regex = qno)[0].split('-')[0]
        return q_no
    
get_question_title_by_qno('Q7')
# Out:
# 'What programming languages do you use on a regular basis? (Select all that apply) '

# %% [markdown]
# ### 🗂 define get_multiple_choice_answer

# %%
answer.filter(regex = 'Q7').describe().loc[['top','count']].T.set_index('top')
# Out:
#             count
# top
# Python      15530
# R            4277
# SQL          7535
# C            3315
# C++          3827
# Java         3367
# Javascript   2995
# Julia         262
# Swift         198
# Bash         1776
# MATLAB       2217
# None          206
# Other        1945

# %%
def get_multiple_choice_answer_by_qno(qno):
    answer_count = answer.filter(regex = 'Q7').describe().loc[['top','count']].T.set_index('top').sort_values(by = 'count', ascending = False)
    return answer_count

get_multiple_choice_answer_by_qno('Q7')
# Out:
#             count
# top
# Python      15530
# SQL          7535
# R            4277
# C++          3827
# Java         3367
# C            3315
# Javascript   2995
# MATLAB       2217
# Other        1945
# Bash         1776
# Julia         262
# None          206
# Swift         198

# %% [markdown]
# ### 📊 define show_multiple_choice_bar_plot_by_qno function

# %%
get_multiple_choice_answer_by_qno('Q7').index
# Out:
# Index(['Python', 'SQL', 'R', 'C++', 'Java', 'C', 'Javascript', 'MATLAB',
#        'Other', 'Bash', 'Julia', 'None', 'Swift'],
#       dtype='object', name='top')

# %%
def show_multiple_choice_bar_plot_by_qno(qno):
    multiple_choice_answer =  get_multiple_choice_answer_by_qno(qno)
        
    plt.figure.Figure(figsize =(10, 6))
    sns.barplot(data = multiple_choice_answer,
                y = multiple_choice_answer.index,
                x = 'count',
                palette = 'Blues_r').set_title(get_question_title_by_qno(qno))
        
show_multiple_choice_bar_plot_by_qno('Q7')

# %%
q7_cols = answer.filter(regex = 'Q7').describe().loc['top'].tolist()
q7_cols
# Out:
# ['Python',
#  'R',
#  'SQL',
#  'C',
#  'C++',
#  'Java',
#  'Javascript',
#  'Julia',
#  'Swift',
#  'Bash',
#  'MATLAB',
#  'None',
#  'Other']

# %% [markdown]
# ### define 📊 show_plot_by_qno

# %%
show_countplot_by_qno('Q1')

# %%
show_multiple_choice_bar_plot_by_qno('Q7')

# %%
def show_plot_by_qno(qno):
    if qno in question.index:
        show_countplot_by_qno(qno)
        print('show_single')
    else:
        show_multiple_choice_bar_plot_by_qno(qno)
        print('show_multiple')

# %%
show_plot_by_qno('Q1')
# Out:
# show_single

# %%
pd.crosstab(answer['Q6'], answer['Q2'])
# Out:
# Q2                          Man  Nonbinary  Prefer not to say  \
# Q6
# 1-2 years                  3433          7                 49
# 10-20 years                1490          5                 35
# 20+ years                  1197          4                 24
# 3-5 years                  3580          7                 47
# 5-10 years                 2077         15                 36
# < 1 years                  2550          7                 32
# I have never written code   772          2                 19
#
# Q2                         Prefer to self-describe  Woman
# Q6
# 1-2 years                                       12   1004
# 10-20 years                                      4    217
# 20+ years                                        7     97
# 3-5 years                                        9    903
# 5-10 years                                       8    416
# < 1 years                                        7    717
# I have never written code                        5    326

# %%
q2q7 = answer.filter(regex = 'Q7|Q2$')
q2q7.describe()
# Out:
#            Q2 Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6  \
# count   20036     15530      4277      7535      3315      3827      3367
# unique      5         1         1         1         1         1         1
# top       Man    Python         R       SQL         C       C++      Java
# freq    15789     15530      4277      7535      3315      3827      3367
#
#          Q7_Part_7 Q7_Part_8 Q7_Part_9 Q7_Part_10 Q7_Part_11 Q7_Part_12  \
# count         2995       262       198       1776       2217        206
# unique           1         1         1          1          1          1
# top     Javascript     Julia     Swift       Bash     MATLAB       None
# freq          2995       262       198       1776       2217        206
#
#        Q7_OTHER
# count      1945
# unique        1
# top       Other
# freq       1945

# %%
q7_cols = answer.filter(regex = 'Q7').describe().loc['top'].tolist()
q7_cols
# Out:
# ['Python',
#  'R',
#  'SQL',
#  'C',
#  'C++',
#  'Java',
#  'Javascript',
#  'Julia',
#  'Swift',
#  'Bash',
#  'MATLAB',
#  'None',
#  'Other']

# %%
answer.filter(regex = 'Q7|Q2$')
# Out:
#           Q2 Q7_Part_1 Q7_Part_2 Q7_Part_3 Q7_Part_4 Q7_Part_5 Q7_Part_6  \
# 1        Man    Python         R       SQL         C       NaN       NaN
# 2        Man    Python         R       SQL       NaN       NaN       NaN
# 3        Man       NaN       NaN       NaN       NaN       NaN      Java
# 4        Man    Python       NaN       SQL       NaN       NaN       NaN
# 5        Man    Python       NaN       NaN       NaN       NaN       NaN
# ...      ...       ...       ...       ...       ...       ...       ...
# 20032    Man       NaN       NaN       NaN       NaN       NaN       NaN
# 20033  Woman    Python       NaN       NaN       NaN       NaN       NaN
# 20034    Man    Python       NaN       NaN       NaN       NaN       NaN
# 20035    Man    Python       NaN       SQL         C       NaN      Java
# 20036    Man    Python       NaN       NaN       NaN       NaN       NaN
#
#         Q7_Part_7 Q7_Part_8 Q7_Part_9 Q7_Part_10 Q7_Part_11 Q7_Part_12  \
# 1      Javascript       NaN       NaN        NaN     MATLAB        NaN
# 2             NaN       NaN       NaN        NaN        NaN        NaN
# 3      Javascript       NaN       NaN       Bash        NaN        NaN
# 4             NaN       NaN       NaN       Bash        NaN        NaN
# 5             NaN       NaN       NaN        NaN        NaN        NaN
# ...           ...       ...       ...        ...        ...        ...
# 20032         NaN       NaN       NaN        NaN        NaN        NaN
# 20033         NaN       NaN       NaN        NaN        NaN        NaN
# 20034         NaN       NaN       NaN        NaN        NaN        NaN
# 20035  Javascript       NaN       NaN        NaN        NaN        NaN
# 20036         NaN       NaN       NaN        NaN        NaN        NaN
#
#       Q7_OTHER
# 1        Other
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ...        ...
# 20032      NaN
# 20033      NaN
# 20034      NaN
# 20035      NaN
# 20036      NaN
#
# [20036 rows x 14 columns]

# %%
answer.filter(regex = 'Q7|Q2$').groupby('Q2').count()
# Out:
#                          Q7_Part_1  Q7_Part_2  Q7_Part_3  Q7_Part_4  \
# Q2
# Man                          12530       3299       5940       2552
# Nonbinary                       41         14         20          8
# Prefer not to say              182         48         97         36
# Prefer to self-describe         41          8         18         12
# Woman                         2736        908       1460        707
#
#                          Q7_Part_5  Q7_Part_6  Q7_Part_7  Q7_Part_8  \
# Q2
# Man                           3063       2641       2487        238
# Nonbinary                       10          1          6          1
# Prefer not to say               43         42         41          5
# Prefer to self-describe         13          9         12          2
# Woman                          698        674        449         16
#
#                          Q7_Part_9  Q7_Part_10  Q7_Part_11  Q7_Part_12  \
# Q2
# Man                            171        1561        1679         149
# Nonbinary                        2          10           7           0
# Prefer not to say                4          31          28           6
# Prefer to self-describe          1          10           6           0
# Woman                           20         164         497          51
#
#                          Q7_OTHER
# Q2
# Man                          1634
# Nonbinary                       7
# Prefer not to say              31
# Prefer to self-describe         7
# Woman                         266

# %%
q2q7_count = answer.filter(regex = 'Q7|Q2$').groupby('Q2').count()
q2q7_count.columns = q7_cols
q2q7_count.columns
# Out:
# Index(['Python', 'R', 'SQL', 'C', 'C++', 'Java', 'Javascript', 'Julia',
#        'Swift', 'Bash', 'MATLAB', 'None', 'Other'],
#       dtype='object')

# %%
q2q7_count
# Out:
#                          Python     R   SQL     C   C++  Java  Javascript  \
# Q2
# Man                       12530  3299  5940  2552  3063  2641        2487
# Nonbinary                    41    14    20     8    10     1           6
# Prefer not to say           182    48    97    36    43    42          41
# Prefer to self-describe      41     8    18    12    13     9          12
# Woman                      2736   908  1460   707   698   674         449
#
#                          Julia  Swift  Bash  MATLAB  None  Other
# Q2
# Man                        238    171  1561    1679   149   1634
# Nonbinary                    1      2    10       7     0      7
# Prefer not to say            5      4    31      28     6     31
# Prefer to self-describe      2      1    10       6     0      7
# Woman                       16     20   164     497    51    266

# %%
q2q7_count.loc[['Man','Woman']].plot.bar()
# Out:
# <AxesSubplot:xlabel='Q2'>

# %%
q2q7_count.loc[['Man', 'Woman']].T
# Out:
# Q2            Man  Woman
# Python      12530   2736
# R            3299    908
# SQL          5940   1460
# C            2552    707
# C++          3063    698
# Java         2641    674
# Javascript   2487    449
# Julia         238     16
# Swift         171     20
# Bash         1561    164
# MATLAB       1679    497
# None          149     51
# Other        1634    266

# %%
q2q7_count.loc[['Man', 'Woman']].T.plot.bar()
# Out:
# <AxesSubplot:>

# %%
q2q7_count.loc[['Man', 'Woman']].T.sort_values('Woman', ascending = True).plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Q24 What is your current yearly compensation (approximate $USD)

# %%
show_plot_by_qno('Q24')
# Out:
# show_single

# %%
answer['Q24'].value_counts()
# Out:
# $0-999             2128
# 10,000-14,999       665
# 1,000-1,999         581
# 100,000-124,999     573
# 40,000-49,999       552
# 30,000-39,999       540
# 50,000-59,999       510
# 5,000-7,499         488
# 15,000-19,999       449
# 60,000-69,999       408
# 20,000-24,999       404
# 70,000-79,999       394
# 7,500-9,999         371
# 150,000-199,999     347
# 2,000-2,999         330
# 125,000-149,999     315
# 25,000-29,999       310
# 90,000-99,999       280
# 4,000-4,999         279
# 80,000-89,999       273
# 3,000-3,999         264
# 200,000-249,999     115
# 300,000-500,000      55
# > $500,000           50
# 250,000-299,999      48
# Name: Q24, dtype: int64

# %%
answer['Q24'].value_counts().reset_index()
# Out:
#               index   Q24
# 0            $0-999  2128
# 1     10,000-14,999   665
# 2       1,000-1,999   581
# 3   100,000-124,999   573
# 4     40,000-49,999   552
# 5     30,000-39,999   540
# 6     50,000-59,999   510
# 7       5,000-7,499   488
# 8     15,000-19,999   449
# 9     60,000-69,999   408
# 10    20,000-24,999   404
# 11    70,000-79,999   394
# 12      7,500-9,999   371
# 13  150,000-199,999   347
# 14      2,000-2,999   330
# 15  125,000-149,999   315
# 16    25,000-29,999   310
# 17    90,000-99,999   280
# 18      4,000-4,999   279
# 19    80,000-89,999   273
# 20      3,000-3,999   264
# 21  200,000-249,999   115
# 22  300,000-500,000    55
# 23       > $500,000    50
# 24  250,000-299,999    48

# %%
q24_count = answer['Q24'].value_counts().reset_index()
q24_count.columns = ['range', 'count']
q24_count
# Out:
#               range  count
# 0            $0-999   2128
# 1     10,000-14,999    665
# 2       1,000-1,999    581
# 3   100,000-124,999    573
# 4     40,000-49,999    552
# 5     30,000-39,999    540
# 6     50,000-59,999    510
# 7       5,000-7,499    488
# 8     15,000-19,999    449
# 9     60,000-69,999    408
# 10    20,000-24,999    404
# 11    70,000-79,999    394
# 12      7,500-9,999    371
# 13  150,000-199,999    347
# 14      2,000-2,999    330
# 15  125,000-149,999    315
# 16    25,000-29,999    310
# 17    90,000-99,999    280
# 18      4,000-4,999    279
# 19    80,000-89,999    273
# 20      3,000-3,999    264
# 21  200,000-249,999    115
# 22  300,000-500,000     55
# 23       > $500,000     50
# 24  250,000-299,999     48

# %%
q24_count.sort_values('range')
# Out:
#               range  count
# 0            $0-999   2128
# 2       1,000-1,999    581
# 1     10,000-14,999    665
# 3   100,000-124,999    573
# 15  125,000-149,999    315
# 8     15,000-19,999    449
# 13  150,000-199,999    347
# 14      2,000-2,999    330
# 10    20,000-24,999    404
# 21  200,000-249,999    115
# 16    25,000-29,999    310
# 24  250,000-299,999     48
# 20      3,000-3,999    264
# 5     30,000-39,999    540
# 22  300,000-500,000     55
# 18      4,000-4,999    279
# 4     40,000-49,999    552
# 7       5,000-7,499    488
# 6     50,000-59,999    510
# 9     60,000-69,999    408
# 12      7,500-9,999    371
# 11    70,000-79,999    394
# 19    80,000-89,999    273
# 17    90,000-99,999    280
# 23       > $500,000     50

# %%
q24_count['range'].str.split('-')
# Out:
# 0              [$0, 999]
# 1       [10,000, 14,999]
# 2         [1,000, 1,999]
# 3     [100,000, 124,999]
# 4       [40,000, 49,999]
# 5       [30,000, 39,999]
# 6       [50,000, 59,999]
# 7         [5,000, 7,499]
# 8       [15,000, 19,999]
# 9       [60,000, 69,999]
# 10      [20,000, 24,999]
# 11      [70,000, 79,999]
# 12        [7,500, 9,999]
# 13    [150,000, 199,999]
# 14        [2,000, 2,999]
# 15    [125,000, 149,999]
# 16      [25,000, 29,999]
# 17      [90,000, 99,999]
# 18        [4,000, 4,999]
# 19      [80,000, 89,999]
# 20        [3,000, 3,999]
# 21    [200,000, 249,999]
# 22    [300,000, 500,000]
# 23          [> $500,000]
# 24    [250,000, 299,999]
# Name: range, dtype: object

# %%
q24_count['min'] = q24_count['range'].str.split('-', expand = True)[0]
q24_count['min']
# Out:
# 0             $0
# 1         10,000
# 2          1,000
# 3        100,000
# 4         40,000
# 5         30,000
# 6         50,000
# 7          5,000
# 8         15,000
# 9         60,000
# 10        20,000
# 11        70,000
# 12         7,500
# 13       150,000
# 14         2,000
# 15       125,000
# 16        25,000
# 17        90,000
# 18         4,000
# 19        80,000
# 20         3,000
# 21       200,000
# 22       300,000
# 23    > $500,000
# 24       250,000
# Name: min, dtype: object

# %%
q24_count['max'] = q24_count['range'].str.split('-', expand = True)[1]
q24_count['max']
# Out:
# 0         999
# 1      14,999
# 2       1,999
# 3     124,999
# 4      49,999
# 5      39,999
# 6      59,999
# 7       7,499
# 8      19,999
# 9      69,999
# 10     24,999
# 11     79,999
# 12      9,999
# 13    199,999
# 14      2,999
# 15    149,999
# 16     29,999
# 17     99,999
# 18      4,999
# 19     89,999
# 20      3,999
# 21    249,999
# 22    500,000
# 23       None
# 24    299,999
# Name: max, dtype: object

# %%
q24_count['min'].str.replace(',', '')
# Out:
# 0            $0
# 1         10000
# 2          1000
# 3        100000
# 4         40000
# 5         30000
# 6         50000
# 7          5000
# 8         15000
# 9         60000
# 10        20000
# 11        70000
# 12         7500
# 13       150000
# 14         2000
# 15       125000
# 16        25000
# 17        90000
# 18         4000
# 19        80000
# 20         3000
# 21       200000
# 22       300000
# 23    > $500000
# 24       250000
# Name: min, dtype: object

# %%
q24_count['min'].str.replace(',|>|\$', '').astype(int)
# Out:
# <ipython-input-522-28d1914048fc>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   q24_count['min'].str.replace(',|>|\$', '').astype(int)
# 0          0
# 1      10000
# 2       1000
# 3     100000
# 4      40000
# 5      30000
# 6      50000
# 7       5000
# 8      15000
# 9      60000
# 10     20000
# 11     70000
# 12      7500
# 13    150000
# 14      2000
# 15    125000
# 16     25000
# 17     90000
# 18      4000
# 19     80000
# 20      3000
# 21    200000
# 22    300000
# 23    500000
# 24    250000
# Name: min, dtype: int32

# %%
q24_count['min'].str.replace(',|>|\$', '').astype(int)
# Out:
# <ipython-input-523-28d1914048fc>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   q24_count['min'].str.replace(',|>|\$', '').astype(int)
# 0          0
# 1      10000
# 2       1000
# 3     100000
# 4      40000
# 5      30000
# 6      50000
# 7       5000
# 8      15000
# 9      60000
# 10     20000
# 11     70000
# 12      7500
# 13    150000
# 14      2000
# 15    125000
# 16     25000
# 17     90000
# 18      4000
# 19     80000
# 20      3000
# 21    200000
# 22    300000
# 23    500000
# 24    250000
# Name: min, dtype: int32

# %%
q24_count['min'] = q24_count['min'].str.replace(',|>|\$', '').astype(int)
q24_count = q24_count.sort_values('min')
# Out:
# <ipython-input-524-ca747a7981ba>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   q24_count['min'] = q24_count['min'].str.replace(',|>|\$', '').astype(int)

# %%
q24_count
# Out:
#               range  count     min      max
# 0            $0-999   2128       0      999
# 2       1,000-1,999    581    1000    1,999
# 14      2,000-2,999    330    2000    2,999
# 20      3,000-3,999    264    3000    3,999
# 18      4,000-4,999    279    4000    4,999
# 7       5,000-7,499    488    5000    7,499
# 12      7,500-9,999    371    7500    9,999
# 1     10,000-14,999    665   10000   14,999
# 8     15,000-19,999    449   15000   19,999
# 10    20,000-24,999    404   20000   24,999
# 16    25,000-29,999    310   25000   29,999
# 5     30,000-39,999    540   30000   39,999
# 4     40,000-49,999    552   40000   49,999
# 6     50,000-59,999    510   50000   59,999
# 9     60,000-69,999    408   60000   69,999
# 11    70,000-79,999    394   70000   79,999
# 19    80,000-89,999    273   80000   89,999
# 17    90,000-99,999    280   90000   99,999
# 3   100,000-124,999    573  100000  124,999
# 15  125,000-149,999    315  125000  149,999
# 13  150,000-199,999    347  150000  199,999
# 21  200,000-249,999    115  200000  249,999
# 24  250,000-299,999     48  250000  299,999
# 22  300,000-500,000     55  300000  500,000
# 23       > $500,000     50  500000     None

# %%
plt.figure.Figure(figsize = (10, 6))
sns.barplot(data = q24_count, x = 'count', y = 'range')
# Out:
# <AxesSubplot:xlabel='count', ylabel='range'>

# %%
q24_cols = q24_count.range.tolist()
q24_cols
# Out:
# ['$0-999',
#  '1,000-1,999',
#  '2,000-2,999',
#  '3,000-3,999',
#  '4,000-4,999',
#  '5,000-7,499',
#  '7,500-9,999',
#  '10,000-14,999',
#  '15,000-19,999',
#  '20,000-24,999',
#  '25,000-29,999',
#  '30,000-39,999',
#  '40,000-49,999',
#  '50,000-59,999',
#  '60,000-69,999',
#  '70,000-79,999',
#  '80,000-89,999',
#  '90,000-99,999',
#  '100,000-124,999',
#  '125,000-149,999',
#  '150,000-199,999',
#  '200,000-249,999',
#  '250,000-299,999',
#  '300,000-500,000',
#  '> $500,000']

# %%
q3_usa = answer[answer['Q3'].isin(['United States of America'])]
plt.figure.Figure(figsize = (10, 6))
sns.countplot(data = q3_usa,
             y = 'Q24',
             order = q24_cols,
             palette = 'Blues_r').set_title('United States of America')
# Out:
# Text(0.5, 1.0, 'United States of America')

# %%
answer[answer['Q3'].isin(['South Korea'])]
# Out:
#       Time from Start to Finish (seconds)     Q1     Q2           Q3  \
# 39                                    592  25-29    Man  South Korea
# 286                                   237  40-44    Man  South Korea
# 471                                   380  22-24  Woman  South Korea
# 557                                   639  30-34    Man  South Korea
# 735                                  1173  25-29    Man  South Korea
# ...                                   ...    ...    ...          ...
# 19536                                 601  45-49    Man  South Korea
# 19703                                 565  18-21  Woman  South Korea
# 19763                                 641  18-21    Man  South Korea
# 19845                                 201  25-29    Man  South Korea
# 19968                                 416  30-34    Man  South Korea
#
#                                                       Q4  \
# 39                                       Master’s degree
# 286                                    Bachelor’s degree
# 471                                    Bachelor’s degree
# 557                                      Doctoral degree
# 735                                    Bachelor’s degree
# ...                                                  ...
# 19536                                  Bachelor’s degree
# 19703  Some college/university study without earning ...
# 19763  Some college/university study without earning ...
# 19845                                    Master’s degree
# 19968                                  Bachelor’s degree
#
#                            Q5          Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  ...  \
# 39     Currently not employed  5-10 years    Python         R       NaN  ...
# 286    Currently not employed   1-2 years    Python       NaN       NaN  ...
# 471                   Student   1-2 years    Python       NaN       NaN  ...
# 557            Data Scientist   3-5 years    Python         R       NaN  ...
# 735                   Student   3-5 years       NaN       NaN       NaN  ...
# ...                       ...         ...       ...       ...       ...  ...
# 19536   DBA/Database Engineer  5-10 years    Python       NaN       SQL  ...
# 19703                 Student   1-2 years    Python       NaN       NaN  ...
# 19763                 Student   < 1 years    Python       NaN       NaN  ...
# 19845                 Student   1-2 years    Python       NaN       SQL  ...
# 19968            Data Analyst   1-2 years    Python       NaN       SQL  ...
#
#       Q35_B_Part_2 Q35_B_Part_3 Q35_B_Part_4   Q35_B_Part_5 Q35_B_Part_6  \
# 39             NaN          NaN          NaN   TensorBoard           NaN
# 286            NaN          NaN          NaN            NaN          NaN
# 471            NaN          NaN          NaN            NaN          NaN
# 557            NaN          NaN          NaN            NaN          NaN
# 735            NaN          NaN          NaN            NaN          NaN
# ...            ...          ...          ...            ...          ...
# 19536          NaN          NaN          NaN            NaN          NaN
# 19703          NaN          NaN          NaN            NaN          NaN
# 19763          NaN          NaN          NaN            NaN          NaN
# 19845          NaN          NaN          NaN            NaN          NaN
# 19968          NaN          NaN          NaN            NaN          NaN
#
#       Q35_B_Part_7 Q35_B_Part_8            Q35_B_Part_9 Q35_B_Part_10  \
# 39             NaN          NaN                     NaN           NaN
# 286            NaN          NaN                     NaN           NaN
# 471            NaN          NaN                     NaN          None
# 557            NaN          NaN                     NaN           NaN
# 735            NaN          NaN                     NaN           NaN
# ...            ...          ...                     ...           ...
# 19536          NaN          NaN                     NaN           NaN
# 19703    Polyaxon           NaN   Domino Model Monitor            NaN
# 19763          NaN          NaN                     NaN          None
# 19845          NaN          NaN                     NaN           NaN
# 19968          NaN          NaN                     NaN           NaN
#
#       Q35_B_OTHER
# 39            NaN
# 286           NaN
# 471           NaN
# 557           NaN
# 735           NaN
# ...           ...
# 19536         NaN
# 19703         NaN
# 19763         NaN
# 19845         NaN
# 19968         NaN
#
# [190 rows x 355 columns]

# %%
q3_korea = answer[answer['Q3'].isin(['South Korea'])]
plt.figure.Figure(figsize = (10, 6))
sns.countplot(data = q3_korea,
             y = 'Q24',
             order = q24_cols,
             palette = 'Blues_r').set_title('South Korea Yearly Compensation')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Q24'>
